# %%
#example using loop.call_soon
# import asyncio
#
# def hello_world(loop):
#     print('Hello World')
#     loop.stop()
#
# loop = asyncio.get_event_loop()
#
# # Schedule a call to hello_world()
# loop.call_soon(hello_world, loop)
#
# # Blocking call interrupted by loop.stop()
# loop.run_forever()
# loop.close()

#example using coroutine
# import asyncio
# import datetime
#
# @asyncio.coroutine
# def display_date(loop):
#     end_time = loop.time() + 5.0
#     while True:
#         print(datetime.datetime.now())
#         if (loop.time() + 1.0) >= end_time:
#             break
#         yield from asyncio.sleep(1)
#
# loop = asyncio.get_event_loop()
# # Blocking call which returns when the display_date() coroutine is done
# loop.run_until_complete(display_date(loop))
# loop.close()



#what we want: poll the api for changes

#requirements:
    # get heartbeat NO NEED
    # get projects
    # keep calling get projects
    # when a project is created or deleted, send alert. in this case, send just print to screen
    # get current components of a project
    # keep calling get components for a specific project
    # when a component is created or deleted, send alert. in this case, send just print to screen


import asyncio
import requests
from pprint import pprint



old_projects = []
old_components = []


@asyncio.coroutine
def get_projects(user, old_projects):
    print(old_projects,"2")
    url = 'https://staging2.osf.io/api/v2/users/{}/nodes'.format(user['id'])
#     print(url)
    
    resp = requests.get(url)
    if resp.status_code == 200:
        projects = resp.json()['data']
        pprint(resp.json()['data'])
#         pprint(projects)
#         pprint(old_projects)
        if projects_changed(projects, old_projects):
            print("projects changed.")
        else:
            print("projects are same.")
        old_projects = projects 
    else:
        yield from four_hundred(resp)

def projects_changed(projects_new, projects_old):
    if len(projects_new) == len(projects_old):
        return True
    else:
        return False


@asyncio.coroutine
def four_hundred(resp):
    print('---------response is 400---------')
    print(resp.text)



@asyncio.coroutine
def main_loop(user):
    while True: #why long time versus just True?
        # repeatedly get projects
        projects = yield from get_projects(user, old_projects)

        # repeatedly get components of selected project.
        # projects = yield from get_projects(user, projects)


loop = asyncio.get_event_loop()

#assume i have a user with some info.
user = requests.get('https://staging2.osf.io/api/v2/users/?filter[fullname]=Himanshu%20Ojha').json()['data'][0]
# pprint(user)

print(old_projects,"1")
loop.run_until_complete(main_loop(user))
loop.close()
# Out:
# [] 1
# [] 2
# [{'category': 'project',
#   'date_created': '2015-02-03T15:36:49.901000',
#   'date_modified': '2015-02-28T23:04:40.832000',
#   'description': 'implement global experiences',
#   'id': 'c8dkn',
#   'links': {'children': {'count': 0,
#                          'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/children/'},
#             'contributors': {'count': 229,
#                              'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/contributors/'},
#             'files': {'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/files/'},
#             'html': 'https://staging2.osf.io/c8dkn/',
#             'pointers': {'count': 0,
#                          'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/pointers/'},
#             'registrations': {'count': 0,
#                               'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/registrations/'},
#             'self': 'https://staging2.osf.io/api/v2/nodes/c8dkn/'},
#   'properties': {'collection': False,
#                  'dashboard': False,
#                  'registration': False},
#   'public': True,
#   'tags': {'system': [], 'user': []},
#   'title': 'Inverse optimal moderator',
#   'type': 'nodes'}]
# projects are same.
# [] 2
# [{'category': 'project',
#   'date_created': '2015-02-03T15:36:49.901000',
#   'date_modified': '2015-02-28T23:04:40.832000',
#   'description': 'implement global experiences',
#   'id': 'c8dkn',
#   'links': {'children': {'count': 0,
#                          'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/children/'},
#             'contributors': {'count': 229,
#                              'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/contributors/'},
#             'files': {'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/files/'},
#             'html': 'https://staging2.osf.io/c8dkn/',
#             'pointers': {'count': 0,
#                          'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/pointers/'},
#             'registrations': {'count': 0,
#                               'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/registrations/'},
#             'self': 'https://staging2.osf.io/api/v2/nodes/c8dkn/'},
#   'properties': {'collection': False,
#                  'dashboard': False,
#                  'registration': False},
#   'public': True,
#   'tags': {'system': [], 'user': []},
#   'title': 'Inverse optimal moderator',
#   'type': 'nodes'}]
# projects are same.
# [] 2
# [{'category': 'project',
#   'date_created': '2015-02-03T15:36:49.901000',
#   'date_modified': '2015-02-28T23:04:40.832000',
#   'description': 'implement global experiences',
#   'id': 'c8dkn',
#   'links': {'children': {'count': 0,
#                          'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/children/'},
#             'contributors': {'count': 229,
#                              'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/contributors/'},
#             'files': {'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/files/'},
#             'html': 'https://staging2.osf.io/c8dkn/',
#             'pointers': {'count': 0,
#                          'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/pointers/'},
#             'registrations': {'count': 0,
#                               'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/registrations/'},
#             'self': 'https://staging2.osf.io/api/v2/nodes/c8dkn/'},
#   'properties': {'collection': False,
#                  'dashboard': False,
#                  'registration': False},
#   'public': True,
#   'tags': {'system': [], 'user': []},
#   'title': 'Inverse optimal moderator',
#   'type': 'nodes'}]
# projects are same.
# [] 2
# [{'category': 'project',
#   'date_created': '2015-02-03T15:36:49.901000',
#   'date_modified': '2015-02-28T23:04:40.832000',
#   'description': 'implement global experiences',
#   'id': 'c8dkn',
#   'links': {'children': {'count': 0,
#                          'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/children/'},
#             'contributors': {'count': 229,
#                              'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/contributors/'},
#             'files': {'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/files/'},
#             'html': 'https://staging2.osf.io/c8dkn/',
#             'pointers': {'count': 0,
#                          'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/pointers/'},
#             'registrations': {'count': 0,
#                               'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/registrations/'},
#             'self': 'https://staging2.osf.io/api/v2/nodes/c8dkn/'},
#   'properties': {'collection': False,
#                  'dashboard': False,
#                  'registration': False},
#   'public': True,
#   'tags': {'system': [], 'user': []},
#   'title': 'Inverse optimal moderator',
#   'type': 'nodes'}]
# projects are same.
# [] 2
# [{'category': 'project',
#   'date_created': '2015-02-03T15:36:49.901000',
#   'date_modified': '2015-02-28T23:04:40.832000',
#   'description': 'implement global experiences',
#   'id': 'c8dkn',
#   'links': {'children': {'count': 0,
#                          'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/children/'},
#             'contributors': {'count': 229,
#                              'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/contributors/'},
#             'files': {'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/files/'},
#             'html': 'https://staging2.osf.io/c8dkn/',
#             'pointers': {'count': 0,
#                          'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/pointers/'},
#             'registrations': {'count': 0,
#                               'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/registrations/'},
#             'self': 'https://staging2.osf.io/api/v2/nodes/c8dkn/'},
#   'properties': {'collection': False,
#                  'dashboard': False,
#                  'registration': False},
#   'public': True,
#   'tags': {'system': [], 'user': []},
#   'title': 'Inverse optimal moderator',
#   'type': 'nodes'}]
# projects are same.
# [] 2
# [{'category': 'project',
#   'date_created': '2015-02-03T15:36:49.901000',
#   'date_modified': '2015-02-28T23:04:40.832000',
#   'description': 'implement global experiences',
#   'id': 'c8dkn',
#   'links': {'children': {'count': 0,
#                          'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/children/'},
#             'contributors': {'count': 229,
#                              'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/contributors/'},
#             'files': {'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/files/'},
#             'html': 'https://staging2.osf.io/c8dkn/',
#             'pointers': {'count': 0,
#                          'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/pointers/'},
#             'registrations': {'count': 0,
#                               'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/registrations/'},
#             'self': 'https://staging2.osf.io/api/v2/nodes/c8dkn/'},
#   'properties': {'collection': False,
#                  'dashboard': False,
#                  'registration': False},
#   'public': True,
#   'tags': {'system': [], 'user': []},
#   'title': 'Inverse optimal moderator',
#   'type': 'nodes'}]
# projects are same.
# [] 2
# [{'category': 'project',
#   'date_created': '2015-02-03T15:36:49.901000',
#   'date_modified': '2015-02-28T23:04:40.832000',
#   'description': 'implement global experiences',
#   'id': 'c8dkn',
#   'links': {'children': {'count': 0,
#                          'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/children/'},
#             'contributors': {'count': 229,
#                              'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/contributors/'},
#             'files': {'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/files/'},
#             'html': 'https://staging2.osf.io/c8dkn/',
#             'pointers': {'count': 0,
#                          'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/pointers/'},
#             'registrations': {'count': 0,
#                               'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/registrations/'},
#             'self': 'https://staging2.osf.io/api/v2/nodes/c8dkn/'},
#   'properties': {'collection': False,
#                  'dashboard': False,
#                  'registration': False},
#   'public': True,
#   'tags': {'system': [], 'user': []},
#   'title': 'Inverse optimal moderator',
#   'type': 'nodes'}]
# projects are same.
# [] 2
# [{'category': 'project',
#   'date_created': '2015-02-03T15:36:49.901000',
#   'date_modified': '2015-02-28T23:04:40.832000',
#   'description': 'implement global experiences',
#   'id': 'c8dkn',
#   'links': {'children': {'count': 0,
#                          'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/children/'},
#             'contributors': {'count': 229,
#                              'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/contributors/'},
#             'files': {'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/files/'},
#             'html': 'https://staging2.osf.io/c8dkn/',
#             'pointers': {'count': 0,
#                          'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/pointers/'},
#             'registrations': {'count': 0,
#                               'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/registrations/'},
#             'self': 'https://staging2.osf.io/api/v2/nodes/c8dkn/'},
#   'properties': {'collection': False,
#                  'dashboard': False,
#                  'registration': False},
#   'public': True,
#   'tags': {'system': [], 'user': []},
#   'title': 'Inverse optimal moderator',
#   'type': 'nodes'}]
# projects are same.
# [] 2
# [{'category': 'project',
#   'date_created': '2015-02-03T15:36:49.901000',
#   'date_modified': '2015-02-28T23:04:40.832000',
#   'description': 'implement global experiences',
#   'id': 'c8dkn',
#   'links': {'children': {'count': 0,
#                          'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/children/'},
#             'contributors': {'count': 229,
#                              'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/contributors/'},
#             'files': {'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/files/'},
#             'html': 'https://staging2.osf.io/c8dkn/',
#             'pointers': {'count': 0,
#                          'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/pointers/'},
#             'registrations': {'count': 0,
#                               'related': 'https://staging2.osf.io/api/v2/nodes/c8dkn/registrations/'},
#             'self': 'https://staging2.osf.io/api/v2/nodes/c8dkn/'},
#   'properties': {'collection': False,
#                  'dashboard': False,
#                  'registration': False},
#   'public': True,
#   'tags': {'system': [], 'user': []},
#   'title': 'Inverse optimal moderator',
#   'type': 'nodes'}]
# projects are same.
# [] 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/himanshu/.virtualenvs/osfoffline/lib/python3.4/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     371             try:  # Python 2.7, use buffering of HTTP responses
# --> 372                 httplib_response = conn.getresponse(buffering=True)
#     373             except TypeError:  # Python 2.6 and older
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-97ff1c0fae7e> in <module>()
#     108
#     109 print(old_projects,"1")
# --> 110 loop.run_until_complete(main_loop(user))
#     111 loop.close()
#     112
#
# /usr/local/lib/python3.4/asyncio/base_events.py in run_until_complete(self, future)
#     261
#     262         future.add_done_callback(_raise_stop_error)
# --> 263         self.run_forever()
#     264         future.remove_done_callback(_raise_stop_error)
#     265         if not future.done():
#
# /usr/local/lib/python3.4/asyncio/base_events.py in run_forever(self)
#     234             while True:
#     235                 try:
# --> 236                     self._run_once()
#     237                 except _StopError:
#     238                     break
#
# /usr/local/lib/python3.4/asyncio/base_events.py in _run_once(self)
#    1046                                    _format_handle(handle), dt)
#    1047             else:
# -> 1048                 handle._run()
#    1049         handle = None  # Needed to break cycles when an exception occurs.
#    1050
#
# /usr/local/lib/python3.4/asyncio/events.py in _run(self)
#     117     def _run(self):
#     118         try:
# --> 119             self._callback(*self._args)
#     120         except Exception as exc:
#     121             cb = _format_callback(self._callback, self._args)
#
# /usr/local/lib/python3.4/asyncio/tasks.py in _step(***failed resolving arguments***)
#     234                 result = coro.send(value)
#     235             else:
# --> 236                 result = next(coro)
#     237         except StopIteration as exc:
#     238             self.set_result(exc.value)
#
# <ipython-input-1-97ff1c0fae7e> in main_loop(user)
#      95     while True: #why long time versus just True?
#      96         # repeatedly get projects
# ---> 97         projects = yield from get_projects(user, old_projects)
#      98
#      99         # repeatedly get components of selected project.
#
# <ipython-input-1-97ff1c0fae7e> in get_projects(user, old_projects)
#      63 #     print(url)
#      64
# ---> 65     resp = requests.get(url)
#      66     if resp.status_code==200:
#      67         projects = resp.json()['data']
#
# /home/himanshu/.virtualenvs/osfoffline/lib/python3.4/site-packages/requests/api.py in get(url, params, **kwargs)
#      67
#      68     kwargs.setdefault('allow_redirects', True)
# ---> 69     return request('get', url, params=params, **kwargs)
#      70
#      71
#
# /home/himanshu/.virtualenvs/osfoffline/lib/python3.4/site-packages/requests/api.py in request(method, url, **kwargs)
#      48
#      49     session = sessions.Session()
# ---> 50     response = session.request(method=method, url=url, **kwargs)
#      51     # By explicitly closing the session, we avoid leaving sockets open which
#      52     # can trigger a ResourceWarning in some cases, and look like a memory leak
#
# /home/himanshu/.virtualenvs/osfoffline/lib/python3.4/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     463         }
#     464         send_kwargs.update(settings)
# --> 465         resp = self.send(prep, **send_kwargs)
#     466
#     467         return resp
#
# /home/himanshu/.virtualenvs/osfoffline/lib/python3.4/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     592
#     593         # Resolve redirects if allowed.
# --> 594         history = [resp for resp in gen] if allow_redirects else []
#     595
#     596         # Shuffle things around if there's history.
#
# /home/himanshu/.virtualenvs/osfoffline/lib/python3.4/site-packages/requests/sessions.py in <listcomp>(.0)
#     592
#     593         # Resolve redirects if allowed.
# --> 594         history = [resp for resp in gen] if allow_redirects else []
#     595
#     596         # Shuffle things around if there's history.
#
# /home/himanshu/.virtualenvs/osfoffline/lib/python3.4/site-packages/requests/sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, **adapter_kwargs)
#     194                 proxies=proxies,
#     195                 allow_redirects=False,
# --> 196                 **adapter_kwargs
#     197             )
#     198
#
# /home/himanshu/.virtualenvs/osfoffline/lib/python3.4/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     571
#     572         # Send the request
# --> 573         r = adapter.send(request, **kwargs)
#     574
#     575         # Total elapsed time of the request (approximately)
#
# /home/himanshu/.virtualenvs/osfoffline/lib/python3.4/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     368                     decode_content=False,
#     369                     retries=self.max_retries,
# --> 370                     timeout=timeout
#     371                 )
#     372
#
# /home/himanshu/.virtualenvs/osfoffline/lib/python3.4/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     542             httplib_response = self._make_request(conn, method, url,
#     543                                                   timeout=timeout_obj,
# --> 544                                                   body=body, headers=headers)
#     545
#     546             # If we're going to release the connection in ``finally:``, then
#
# /home/himanshu/.virtualenvs/osfoffline/lib/python3.4/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     372                 httplib_response = conn.getresponse(buffering=True)
#     373             except TypeError:  # Python 2.6 and older
# --> 374                 httplib_response = conn.getresponse()
#     375         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     376             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.4/http/client.py in getresponse(self)
#    1170             response = self.response_class(self.sock, method=self._method)
#    1171
# -> 1172         response.begin()
#    1173         assert response.will_close != _UNKNOWN
#    1174         self.__state = _CS_IDLE
#
# /usr/local/lib/python3.4/http/client.py in begin(self)
#     349         # read until we get a non-100 response
#     350         while True:
# --> 351             version, status, reason = self._read_status()
#     352             if status != CONTINUE:
#     353                 break
#
# /usr/local/lib/python3.4/http/client.py in _read_status(self)
#     311
#     312     def _read_status(self):
# --> 313         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     314         if len(line) > _MAXLINE:
#     315             raise LineTooLong("status line")
#
# /usr/local/lib/python3.4/socket.py in readinto(self, b)
#     369         while True:
#     370             try:
# --> 371                 return self._sock.recv_into(b)
#     372             except timeout:
#     373                 self._timeout_occurred = True
#
# /usr/local/lib/python3.4/ssl.py in recv_into(self, buffer, nbytes, flags)
#     744                   "non-zero flags not allowed in calls to recv_into() on %s" %
#     745                   self.__class__)
# --> 746             return self.read(nbytes, buffer)
#     747         else:
#     748             return socket.recv_into(self, buffer, nbytes, flags)
#
# /usr/local/lib/python3.4/ssl.py in read(self, len, buffer)
#     616         try:
#     617             if buffer is not None:
# --> 618                 v = self._sslobj.read(len, buffer)
#     619             else:
#     620                 v = self._sslobj.read(len or 1024)
#
# KeyboardInterrupt:
